# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from bokeh.layouts import column, gridplot, row
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Select
from bokeh.models.callbacks import CustomJS
import numpy as np
import scipy.stats

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3ffb2e79-841c-4343-a13c-c5b236a0c0c9">Loading BokehJS ...</span>
#     </div>

# %%
column_labels = ["Channel","Region","Fresh","Milk","Grocery","Frozen","Detergents_Paper","Delicassen"]
complete_data = np.loadtxt("Wholesale_customers data.csv", dtype=int, skiprows=1, delimiter=',')

# %%
with open("Wholesale_customers_data-missing.csv") as f:
    next(f)
    r=1
    rc_list=[] #row,column tuple of missing value
    missing = 0
    m_data= []
    for line in f:
        l = line.strip('\n').split(',')
        for i,val in enumerate(l):
            if not val:
                missing = missing +1
                tup = (r,i)
                rc_list.append(tup)
                l[i]=0
        m_data.append(tuple(l))
        r=r+1
    print("%d missing values found on (row,col): "%(missing)+" ".join(str(t) for t in rc_list))
missing_data = np.asarray(m_data, dtype=float)
#remove rows with missing data, try linear regression on each column that is missing
clean_data = np.delete(missing_data,[76,173,181,226,275,371],0)

actual_values = dict()
for tup in rc_list:
    actual_values[tup] = complete_data[tup[0],tup[1]]
    print("At %s actual value is %d"%(str(tup),actual_values[tup]))
# Out:
# 6 missing values found on (row,col): (76, 4) (173, 4) (181, 3) (226, 6) (275, 7) (371, 6)
# At (76, 4) actual value is 6532
# At (173, 4) actual value is 19805
# At (181, 3) actual value is 29627
# At (226, 6) actual value is 2568
# At (275, 7) actual value is 379
# At (371, 6) actual value is 716

# %%
CHANNEL = 0
REGION = 1
FRESH = 2
MILK = 3
GROCERY = 4
FROZEN = 5
DETERGENTS =6
DELICASSEN = 7

def plot_distribution(attr_name, calculated_attr_column,clean_attr_column):
    
    clean_density, clean_edge = np.histogram(clean_attr_column, density=True,bins=40)
    clean_unity_density = clean_density/clean_density.sum()
 
    
    calculated_density, calculated_edge = np.histogram(calculated_attr_column, density=True,bins=40)
    calculated_unity_density = calculated_density/calculated_density.sum()

    
    mu, sigma = np.mean(clean_attr_column), np.std(clean_attr_column)
    p1 = figure(title="[Clean]Dist. of ann. $ on %s"%(attr_name),background_fill_color="white")
    p1.quad(top=clean_unity_density, bottom=0, left=clean_edge[:-1], right=clean_edge[1:], fill_color='blue', line_color='blue')
    p1.xaxis.axis_label = '%s (μ=%0.2f, σ=%0.2f)'%(attr_name,mu,sigma)
    p1.yaxis.axis_label = 'Prob(spend on %s)'%(attr_name)
    
    mu, sigma = np.mean(calculated_attr_column), np.std(calculated_attr_column)
    p2 = figure(title="[Calculated]Dist. of ann. $ on %s"%(attr_name),background_fill_color="white")
    p2.quad(top=calculated_unity_density, bottom=0, left=calculated_edge[:-1], right=calculated_edge[1:], fill_color='blue', line_color='blue')
    p2.xaxis.axis_label = 'Annual spending on %s (μ=%0.2f, σ=%0.2f)'%(attr_name,mu,sigma)
    p2.yaxis.axis_label = 'Prob(spend on %s)'%(attr_name)
    return p1,p2

# %%
#Method 1: Take a simple average of each column, use this in place of missing value
missing_cols = set(t[1] for t in rc_list)
col_avg = dict()
missing_col_counts = dict()

for t in rc_list:
    missing_col_counts[t[1]] = missing_col_counts.get(t[1], 0) + 1

for col in missing_cols:
    c = missing_data[:,col]
    avg = sum(c)/(len(c) - missing_col_counts[col])
    col_avg[col] = avg
    print("col %d avg is %.2f"%(col,avg))
    #replace values manually
    if col == 3:
        missing_data[181,3] = avg
    if col == 4:
        missing_data[76,4] = avg
        missing_data[173,4] = avg
    if col == 6:
        missing_data[226,6] = avg
        missing_data[371,6] = avg
    if col == 7:
        missing_data[275,7] = avg
rmse_meanvals = rmse(actual_vals, mean_vals)

affected_cols = {
    "Milk": (missing_data[:,MILK],clean_data[:,MILK]),
    "Grocery": (missing_data[:,GROCERY],clean_data[:,MILK]),
    "Detergents/Paper": (missing_data[:,DETERGENTS],clean_data[:,MILK]),
    "Deelicassen":(missing_data[:,DELICASSEN],clean_data[:,MILK])
}
p = [None]*8
for i, attr_name in enumerate(affected_cols.keys()):
    calculated_attr_column,clean_attr_column = affected_cols[attr_name][0],affected_cols[attr_name][1]
    p[2*i], p[2*i+1] = plot_distribution(attr_name, calculated_attr_column,clean_attr_column)
    
show(gridplot(p,  ncols=2, plot_width=400, plot_height=400))

#Left: distribution of data with rows containing missing values removed
#Right: distribution of data with missing values replaced by column average
# Out:
# col 3 avg is 5766.50
# col 4 avg is 7963.53
# col 6 avg is 2892.58
# col 7 avg is 1525.56
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dd45c631-fbe0-48ad-8e85-0772d1a9371e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dd45c631-fbe0-48ad-8e85-0772d1a9371e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dd45c631-fbe0-48ad-8e85-0772d1a9371e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dd45c631-fbe0-48ad-8e85-0772d1a9371e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8f2d398d-b42d-4f72-bd03-29ff9e2a6f81":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0956c153-544b-428c-b4db-4bdee6f2910c","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"0956c153-544b-428c-b4db-4bdee6f2910c","type":"BoxAnnotation"},"plot":{"id":"8cebcb3d-04ca-4090-ac99-a038873636b4","subtype":"Figure","type":"Plot"}},"id":"5b71c709-1b41-48a9-a946-deea34741667","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8cebcb3d-04ca-4090-ac99-a038873636b4","subtype":"Figure","type":"Plot"}},"id":"dcfe7675-32a5-48f7-864e-52dd7f7895e1","type":"SaveTool"},{"attributes":{"plot":{"id":"8cebcb3d-04ca-4090-ac99-a038873636b4","subtype":"Figure","type":"Plot"}},"id":"d174962f-f889-43a4-ae61-239818410169","type":"ResetTool"},{"attributes":{"plot":{"id":"8cebcb3d-04ca-4090-ac99-a038873636b4","subtype":"Figure","type":"Plot"}},"id":"85c9e64e-667f-4d81-8362-4f17aad30012","type":"HelpTool"},{"attributes":{"plot":{"id":"d04feee0-53ef-4de3-a92b-ef23b46cbd98","subtype":"Figure","type":"Plot"},"ticker":{"id":"2339a1c8-96ab-4386-a85b-dccda90493d1","type":"BasicTicker"}},"id":"fcc1f63e-c77f-416a-a128-b46b4c5c1f67","type":"Grid"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"85852696-05d9-4bba-84e8-ecba1a60c4e2","type":"LinearAxis"}],"left":[{"id":"f011f880-5dc0-488c-b09a-f9325c305056","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"85852696-05d9-4bba-84e8-ecba1a60c4e2","type":"LinearAxis"},{"id":"fcc1f63e-c77f-416a-a128-b46b4c5c1f67","type":"Grid"},{"id":"f011f880-5dc0-488c-b09a-f9325c305056","type":"LinearAxis"},{"id":"9a1fb23e-1c68-493b-9232-42c69eb58869","type":"Grid"},{"id":"0513ce5e-5567-4c8e-81b8-3b555c718542","type":"BoxAnnotation"},{"id":"038e86d6-3e41-4333-a7e4-8b8f1fd9e1cb","type":"GlyphRenderer"}],"title":{"id":"118fd56d-5ce1-46c2-9fb4-04b1dc49b5c4","type":"Title"},"tool_events":{"id":"deeb2df1-d3ea-4fb9-b12e-e609eaae9eeb","type":"ToolEvents"},"toolbar":{"id":"2c26b583-1c8e-490b-a6ea-2c5cdb8bfdac","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"7331f428-b179-4edd-926d-7914b9d41fb7","type":"DataRange1d"},"x_scale":{"id":"c1fc1851-4d9f-4619-8b9e-28d9c89a361f","type":"LinearScale"},"y_range":{"id":"c2434f55-0ccf-45f9-a14a-0b70dba8e9e9","type":"DataRange1d"},"y_scale":{"id":"cfaed21c-213e-44b3-b363-892f1c5732c0","type":"LinearScale"}},"id":"d04feee0-53ef-4de3-a92b-ef23b46cbd98","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"cfaed21c-213e-44b3-b363-892f1c5732c0","type":"LinearScale"},{"attributes":{"plot":null,"text":"[Calclculated]Dist. of ann. $ on Deelicassen"},"id":"118fd56d-5ce1-46c2-9fb4-04b1dc49b5c4","type":"Title"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"blue"},"left":{"field":"left"},"line_color":{"value":"blue"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2ad711f6-c81c-4780-b68e-f06046ccb50d","type":"Quad"},{"attributes":{},"id":"deeb2df1-d3ea-4fb9-b12e-e609eaae9eeb","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ca255e97-d2c6-49e6-bf6c-233fe4b74321","type":"PanTool"},{"id":"08223e4b-bbf3-46ae-8753-1d8740e562f1","type":"WheelZoomTool"},{"id":"b968fd6a-6ca5-4813-84ea-5642656ac878","type":"BoxZoomTool"},{"id":"f6809728-0aad-4346-b5ef-b1898c985c62","type":"SaveTool"},{"id":"0411ba46-b522-4e75-968e-3022ee8e9b10","type":"ResetTool"},{"id":"083f2141-9f30-4b91-89fd-12ab733b0078","type":"HelpTool"}]},"id":"2c26b583-1c8e-490b-a6ea-2c5cdb8bfdac","type":"Toolbar"},{"attributes":{},"id":"c1fc1851-4d9f-4619-8b9e-28d9c89a361f","type":"LinearScale"},{"attributes":{"axis_label":"Annual spending on Deelicassen (\u03bc=1524.86 ...

# %%
#Method 2: Use linear regression, model other parameters -> predict column of missing value
from sklearn.linear_model import LinearRegression
for col in missing_cols:
    print("predicting in column %d"%(col))
    #extract the column we are trying to predict
    y_train = clean_data[:,col]
    #remove the column we are trying to predict from the dat
    X_train = np.delete(clean_data, col ,1)
    
    #get the rows that have missing vals for this column
    rows_to_predict = [t[0] for t in rc_list if t[1] == col]
    missing_rows = missing_data[rows_to_predict]
    X_test = np.delete(missing_rows, col, 1)
    
    #train model
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    
    #predict missing values 
    y_pred_lr = lr.predict(X_test)
    
    av = [actual_values[(r,col)] for r in rows_to_predict]
    
    print("predicted: "+str(y_pred_lr) + " actual values "+ str(av))
    if col == 3:
        missing_data[181,3] = y_pred_lr[0]
    if col == 4:
        missing_data[76,4] = y_pred_lr[0]
        missing_data[173,4] = y_pred_lr[1]
    if col == 6:
        missing_data[226,6] = y_pred_lr[0]
        missing_data[371,6] = y_pred_lr[1]
    if col == 7:
        missing_data[275,7] = y_pred_lr[0]
        
affected_cols = {
    "Milk": (missing_data[:,MILK],clean_data[:,MILK]),
    "Grocery": (missing_data[:,GROCERY],clean_data[:,MILK]),
    "Detergents/Paper": (missing_data[:,DETERGENTS],clean_data[:,MILK]),
    "Deelicassen":(missing_data[:,DELICASSEN],clean_data[:,MILK])
}
p = [None]*8
for i, attr_name in enumerate(affected_cols.keys()):
    calculated_attr_column,clean_attr_column = affected_cols[attr_name][0],affected_cols[attr_name][1]
    p[2*i], p[2*i+1] = plot_distribution(attr_name, calculated_attr_column,clean_attr_column)
    
show(gridplot(p,  ncols=2, plot_width=400, plot_height=400))


#Left: distribution of data with rows containing missing values removed
#Right: distribution of data with missing values replaced by column average
# Out:
# predicting in column 3
# predicted: [ 16800.20264878] actual values [29627]
# predicting in column 4
# predicted: [  3022.60187191  19315.51620873] actual values [6532, 19805]
# predicting in column 6
# predicted: [ 3941.98412068  -281.89007455] actual values [2568, 716]
# predicting in column 7
# predicted: [ 308.92353506] actual values [379]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5438017f-f200-421a-94cb-6282ce715376"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5438017f-f200-421a-94cb-6282ce715376");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5438017f-f200-421a-94cb-6282ce715376");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5438017f-f200-421a-94cb-6282ce715376' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8b14eacf-b596-4b0f-9001-9db6cfee7161":{"roots":{"references":[{"attributes":{"plot":{"id":"98bca8a1-b741-418e-b92f-c2289de32dd7","subtype":"Figure","type":"Plot"}},"id":"b01a3005-5b63-4ab6-a820-99c1279f4821","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1fc6280d-b566-4cce-8814-e386d70ce4fe","type":"BoxAnnotation"},{"attributes":{},"id":"7b714ef8-7a60-42cd-8d02-96c5b957aaa5","type":"ToolEvents"},{"attributes":{"plot":{"id":"31710a6c-a55f-4120-86e3-cb9a3b643c3c","subtype":"Figure","type":"Plot"}},"id":"60f64796-b25f-4050-8233-dda32d158f25","type":"SaveTool"},{"attributes":{"callback":null},"id":"f1b0e381-f92d-4e63-8d03-eab504c4276b","type":"DataRange1d"},{"attributes":{"plot":{"id":"31710a6c-a55f-4120-86e3-cb9a3b643c3c","subtype":"Figure","type":"Plot"}},"id":"bfbe89c9-df37-471d-be45-79c49a7e8039","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b0ad28f0-4cef-433c-9977-da73cf1f3eef","type":"PanTool"},{"id":"4de97055-a66e-4395-be89-f84f623f9829","type":"WheelZoomTool"},{"id":"dd44c62e-7af7-42e4-8e51-127a820055bb","type":"BoxZoomTool"},{"id":"2b0f55a6-e12c-44dd-8adc-044c857b6b7e","type":"SaveTool"},{"id":"1b6ac00b-a4f2-4d03-b440-40a69f0910ec","type":"ResetTool"},{"id":"32a4662b-1971-4f6a-96c0-8ff075e212e1","type":"HelpTool"}]},"id":"e408677e-b012-4965-b7d2-40db0325b768","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[40]},"right":{"__ndarray__":"...","dtype":"float64","shape":[40]},"top":{"__ndarray__":"...","dtype":"float64","shape":[40]}}},"id":"47188b56-649b-4673-a9be-ce33e3c11ee7","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"0b2f52fb-50e2-45c3-b4c0-380b766b6ebd","type":"BoxAnnotation"},"plot":{"id":"98bca8a1-b741-418e-b92f-c2289de32dd7","subtype":"Figure","type":"Plot"}},"id":"60874dec-dbd2-45b5-8c6a-39cf7a44184c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"31710a6c-a55f-4120-86e3-cb9a3b643c3c","subtype":"Figure","type":"Plot"}},"id":"69d7f556-51d6-4be7-80a2-3309327f73fb","type":"HelpTool"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"4a2f7764-edc0-47a7-ac19-a1164f4a6dc7","type":"LinearAxis"}],"left":[{"id":"d22482d8-0ee7-48c5-a02e-c31a322d4e9a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"4a2f7764-edc0-47a7-ac19-a1164f4a6dc7","type":"LinearAxis"},{"id":"28c8bee3-ec75-44d0-9e14-89c86b75a874","type":"Grid"},{"id":"d22482d8-0ee7-48c5-a02e-c31a322d4e9a","type":"LinearAxis"},{"id":"0e6b1d63-4528-4bab-95ce-b62003310dae","type":"Grid"},{"id":"d2a3fa18-0ed8-4f15-9695-c2d92e17f2a1","type":"BoxAnnotation"},{"id":"42591349-7e56-4942-82fa-89df0b9ff966","type":"GlyphRenderer"}],"title":{"id":"23684a9d-60b8-4db3-967a-63064d8421f0","type":"Title"},"tool_events":{"id":"46483c24-433c-4278-bbb6-c61445152205","type":"ToolEvents"},"toolbar":{"id":"71dbefe6-5eb9-43bc-84a5-9b09d92ac709","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"87bd6716-cfe0-4af9-a71a-ef59fe89e10b","type":"DataRange1d"},"x_scale":{"id":"d8eed0ec-5c07-4793-9ced-2cecd58a8ac3","type":"LinearScale"},"y_range":{"id":"b689a203-4133-42bd-9bc8-8c1c55579dda","type":"DataRange1d"},"y_scale":{"id":"da526e59-bdab-414d-8728-610414162b58","type":"LinearScale"}},"id":"e2e09ec7-ebca-484b-8d6d-37f537e33b98","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":n ...

# %%
#calculate rmse
import math
def rmse(y_true, y_pred):
    sq_err = 0
    for yt, yp in zip(y_true,y_pred):
        sq_err = sq_err + math.pow((yt-yp),2)
    mean_sq_err = sq_err/len(y_pred)
    rmse_ = math.sqrt(mean_sq_err)
    return rmse_

# %%
#replacing with mean
#written out by hand because i was running out of time haha
#values are organized by increasing columns (3,4,6,7) and then increasing row 
actual_vals = [29627, 6532, 19805, 2568, 716, 379]
mean_vals = [5795.72, 7972.66, 7972.66, 2891.72, 2891.72, 1525.72]
lr_vals = [16800.20264878, 3022.60187191, 19315.51620873, 3941.98412068, -281.89007455, 308.92353506] 

rmse_meanvals = rmse(actual_vals, mean_vals)
rmse_lr = rmse(actual_vals, lr_vals)

print("RMSE of replacing with mean value for column %0.2f"%(rmse_meanvals))
print("RMSE of replacing with predicted linear regression value for missing value in row %0.2f"%(rmse_lr))

#RMSE of using linear regression is smaller than when just replacing with column mean
#The distribution plots look closer to 'clean' data for linear regression than for replace with mean
# Out:
# RMSE of replacing with mean value for column 10925.22
# RMSE of replacing with predicted linear regression value for missing value in row 5476.78
